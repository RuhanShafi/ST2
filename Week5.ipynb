# %% [markdown]
# 1. Suppose you push the numbers 10, 20, 30, and 40 onto the stack in that order. Then you pop three items. Which one is left on the stack?
#
# Answer: 10 - (Stack is LIFO → last in = 40, popped first → remaining is 10)
#
# 2. Queues can wrap around (circular array), stacks typically do not.
#
# 3. LIFO: Last In, First Out - FIFO: First In, First Out
#
# 4. True or False: A stack or a queue often serves as the underlying mechanism on which an array data type is based - False
#
# 5. As other items are inserted and removed, does a particular item in a queue move along the array - No
#
# 6. Suppose you insert 15, 25, 35, and 45 into a queue. Then you remove three items. Which one is left? - 45
#
# 7.
